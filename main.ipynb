# %%
from utils import llama

prompt = """
    Who is Mark Zugkerbert
"""
response = llama(prompt)
print(response)
# Out:
# I couldn't find any information on a person named "Mark Zugkerbert." It's possible that the name might be misspelled or not widely recognized. If you could provide more context or details about who Mark Zugkerbert is or what he is known for, I would do my best to help.
