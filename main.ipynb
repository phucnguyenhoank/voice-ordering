# %%
from utils import llama

prompt = """
    Who is Mark Zugkerbert
"""
response = llama(prompt)
print(response)
# Out:
# [RESPONSE]<Response [200]>[/RESPONSE]
# {'model': 'llama3.1', 'created_at': '2025-08-09T06:32:01.0978515Z', 'response': "You're probably thinking of Mark Zuckerberg, the CEO and co-founder of Meta (formerly Facebook). He's a well-known American technology entrepreneur, business magnate, and philanthropist.", 'done': True, 'done_reason': 'stop', 'context': [128006, 882, 128007, 271, 58, 65562, 933, 262, 10699, 374, 4488, 77816, 7197, 9339, 198, 25130, 65562, 60, 128009, 128006, 78191, 128007, 271, 2675, 2351, 4762, 7422, 315, 4488, 67034, 11, 279, 12432, 323, 1080, 36927, 315, 16197, 320, 70614, 5690, 570, 1283, 596, 264, 1664, 22015, 3778, 5557, 29349, 11, 2626, 8622, 349, 11, 323, 58738, 897, 380, 13], 'total_duration': 21306314100, 'load_duration': 11085962200, 'prompt_eval_count': 24, 'prompt_eval_duration': 3206996100, 'eval_count': 38, 'eval_duration': 7011618400}
